# %% [markdown]
# ## Read a .csv file from a URL with pandas
#
# ##### Target website : https://www.football-data.co.uk/englandm.php

# %%
import pandas as pd

# %%
# reading 1 csv file from the website
df_premiere1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E0.csv")

#showing dataframe
df_premiere1
# Out:
#     Div        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H     1
# 1    E0  14/08/2021  12:30  Man United           Leeds     5     1   H     1
# 2    E0  14/08/2021  15:00     Burnley        Brighton     1     2   A     1
# 3    E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H     2
# 4    E0  14/08/2021  15:00     Everton     Southampton     3     1   H     0
# ..   ..         ...    ...         ...             ...   ...   ...  ..   ...
# 164  E0  16/12/2021  20:00   Liverpool       Newcastle     3     1   H     2
# 165  E0  18/12/2021  17:30       Leeds         Arsenal     1     4   A     0
# 166  E0  19/12/2021  14:00   Newcastle        Man City     0     4   A     0
# 167  E0  19/12/2021  14:00      Wolves         Chelsea     0     0   D     0
# 168  E0  19/12/2021  16:30   Tottenham       Liverpool     2     2   D     1
#
# ...

# %%
# rename columns
df_premiere1.rename(columns={'Div':'Division'},inplace=True)

#show dataframe
df_premiere1
# Out:
#     Division        Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0         E0  13/08/2021  20:00   Brentford         Arsenal     2     0   H
# 1         E0  14/08/2021  12:30  Man United           Leeds     5     1   H
# 2         E0  14/08/2021  15:00     Burnley        Brighton     1     2   A
# 3         E0  14/08/2021  15:00     Chelsea  Crystal Palace     3     0   H
# 4         E0  14/08/2021  15:00     Everton     Southampton     3     1   H
# ..       ...         ...    ...         ...             ...   ...   ...  ..
# 164       E0  16/12/2021  20:00   Liverpool       Newcastle     3     1   H
# 165       E0  18/12/2021  17:30       Leeds         Arsenal     1     4   A
# 166       E0  19/12/2021  14:00   Newcastle        Man City     0     4   A
# 167       E0  19/12/2021  14:00      Wolves         Chelsea     0     0   D
# 168       E0  19/12/2021  16:30   Tottenham       Liverpool     2     2   D
#
# ...
